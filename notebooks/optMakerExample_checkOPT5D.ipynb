# %% [markdown]
# # I need to check for >3 points operators since the benchmark results are super weird!

# %%
using Pkg
using Metal

cd(@__DIR__)
Pkg.activate("../")
ParamFile = "../config/testparam.csv"  # maybe GeoPoints and planet1D should be fusioned

# batchGPU should be at this level (I have not made it as a module yet, since the choice of Metal/CUDA should be done in a manual way)
include("../src/batchFiles/batchGPU.jl")


include("../src/commonBatchs.jl")
include("../src/planet1D.jl")
include("../src/GeoPoints.jl")

include("../src/flexOPT.jl")

using .commonBatchs, .planet1D, .GeoPoints, .flexOPT
# Out:
#   Activating
# devs = Metal.devices() = Metal.MTL.MTLDeviceInstance[Metal.MTL.MTLDeviceInstance (object of type AGXG13XDevice)]
# project at `~/Documents/Github/flexOPT`
# → Using Metal backend (1 device(s))
# Selected backend type: MetalBackend

# %% [markdown]
# input parameters

# %%
#famousEquationType="2DacousticTime"
#Δ = (1.0,1.0,1.0)
#famousEquationType="1DsismoFreqHomo" # GT95
#famousEquationType="1DsismoTimeHomo" #GT98
#famousEquationType="3DsismoTimeIso" 
famousEquationType="1DpoissonHomo" 
Δ = (1.0)

# orders: -1 -> indicator function, 0 -> box car, >=1 -> B-spline
# Out:
# 1.0

# %% [markdown]
# # first indicator function (3points)

# %%
orderBspace=-1
orderBtime=-1


pointsInSpace=3
pointsInTime=1

# the order of errors to be controlled
supplementaryOrder=1

# new parameters for interpolated Taylor expansion μ for field

fieldItpl = (ptsSpace = 1,ptsTime = 1,offsetSpace=1,offsetTime=1,YorderBspace=-1,YorderBtime=1) #offsetSpace and offsetTime ∈ z 
# μ points should be distributed from y_min+offset*Δy to y_max-offset*Δy offset can be negative too


# new parameters for interpolated Taylor expansion μᶜ for material
materItpl = (ptsSpace = 1,ptsTime = 1,offsetSpace=1,offsetTime=1,YorderBspace=-1,YorderBtime=1)

concreteParametersForOPTConstruction = @strdict famousEquationType Δ orderBtime orderBspace pointsInSpace pointsInTime supplementaryOrder fieldItpl materItpl

optRec = makeOPTsemiSymbolic(concreteParametersForOPTConstruction)
recette = optRec["recette"]
Ajiννᶜ = optRec["recette"].lhs.Ajiννᶜ
# Out:
# (vars, iVars) = (κ, 1)
# (vars, iVars) = (κ, 1)
# pointsIndices = availablePointsConfigurations[iConfigGeometry] = SVector{1, Int64}[[1], [2], [3]]
# middleLinearν = centrePointConfigurations[iConfigGeometry] = 2
# μPoints = availableμPoints[iConfigGeometry] = SVector{1, Float64}[[2.0]]
# μᶜPoints = availableμᶜPoints[iConfigGeometry] = SVector{1, Float64}[[2.0]]
# μaxes = availableμaxes[iConfigGeometry] = ([2.0],)
# μᶜaxes = availableμᶜaxes[iConfigGeometry] = ([2.0],)
# size(μPoints) = (1,)
# pointν = pointsIndices[middleLinearν] = [2]
# (typeof(μPoints), μPoints[1], typeof(pointsIndices)) = (Vector{SVector{1, Float64}}, [2.0], Vector{SVector{1, Int64}})
# nTotalSmallα = sum((length(bigα[iExpr, iField]) for iField = 1:NtypeofFields, iExpr = 1:NtypeofExpr)) = 1
# all_sizes = collect.(size.(coefWYYKK)) = [[4, 4, 1, 1, 1]]
# typeof(output_gpu) = MtlArray{Float32, 4, Metal.PrivateStorage}
# "GPU computation of Ajiννᶜ: done" = "GPU computation of Ajiννᶜ: done"
# nodeValue = eachα.node = κ
# (vars, iVars) = (f(x), 1)
# (vars, iVars) = (f(x), 1)
# pointsIndices = availablePointsConfigurations[iConfigGeometry] = SVector{1, Int64}[[1], [2], [3]]
# middleLinearν = centrePointConfigurations[iConfigGeometry] = 2
# μPoints = availableμPoints[iConfigGeometry] = SVector{1, Float64}[[2.0]]
# μᶜPoints = availableμᶜPoints[iConfigGeometry] = SVector{1, Float64}[[2.0]]
# μaxes = availableμaxes[iConfigGeometry] = ([2.0],)
# μᶜaxes = availableμᶜaxes[iConfigGeometry] = ([2.0],)
# size(μPoints) = (1,)
# pointν = pointsIndices[middleLinearν] = [2]
# (typeof(μPoints), μPoints[1], typeof(pointsIndices)) = (Vector{SVector{1, Float64}}, [2.0], Vector{SVector{1, Int64}})
# nTotalSmallα = sum((length(bigα[iExpr, iField]) for iField = 1:NtypeofFields, iExpr = 1:NtypeofExpr)) = 1
# all_sizes = collect.(size.(coefWYYKK)) = [[4, 4, 1, 1, 1]]
# typeof(output_gpu) = MtlArray{Float32, 4, Metal.PrivateStorage}
# "GPU computation of Ajiννᶜ: done" = "GPU computation of Ajiννᶜ: done"
# nodeValue = eachα.node = 1
# 3×1×1×1 Array{Symbolics.Num, 4}:
# [:, :, 1, 1] =
#   2.0κ₁
#  -4.0κ₁
#   2.0κ₁

# %% [markdown]
# # now with B-spline

# %%
orderBspace=1
orderBtime=1


pointsInSpace=3
pointsInTime=1

# the order of errors to be controlled
supplementaryOrder=1

# new parameters for interpolated Taylor expansion μ for field

fieldItpl = (ptsSpace = 1,ptsTime = 1,offsetSpace=1,offsetTime=1,YorderBspace=-1,YorderBtime=1) #offsetSpace and offsetTime ∈ z 
# μ points should be distributed from y_min+offset*Δy to y_max-offset*Δy offset can be negative too


# new parameters for interpolated Taylor expansion μᶜ for material
materItpl = (ptsSpace = 1,ptsTime = 1,offsetSpace=1,offsetTime=1,YorderBspace=-1,YorderBtime=1)

concreteParametersForOPTConstruction = @strdict famousEquationType Δ orderBtime orderBspace pointsInSpace pointsInTime supplementaryOrder fieldItpl materItpl
optRec = makeOPTsemiSymbolic(concreteParametersForOPTConstruction)
recette = optRec["recette"]
Ajiννᶜ = optRec["recette"].lhs.Ajiννᶜ
# Out:
# (vars, iVars) = (κ, 1)
# (vars, iVars) = (κ, 1)
# pointsIndices = availablePointsConfigurations[iConfigGeometry] = SVector{1, Int64}[[1], [2], [3]]
# middleLinearν = centrePointConfigurations[iConfigGeometry] = 2
# μPoints = availableμPoints[iConfigGeometry] = SVector{1, Float64}[[2.0]]
# μᶜPoints = availableμᶜPoints[iConfigGeometry] = SVector{1, Float64}[[2.0]]
# μaxes = availableμaxes[iConfigGeometry] = ([2.0],)
# μᶜaxes = availableμᶜaxes[iConfigGeometry] = ([2.0],)
# size(μPoints) = (1,)
# pointν = pointsIndices[middleLinearν] = [2]
# (typeof(μPoints), μPoints[1], typeof(pointsIndices)) = (Vector{SVector{1, Float64}}, [2.0], Vector{SVector{1, Int64}})
# nTotalSmallα = sum((length(bigα[iExpr, iField]) for iField = 1:NtypeofFields, iExpr = 1:NtypeofExpr)) = 1
# all_sizes = collect.(size.(coefWYYKK)) = [[4, 4, 1, 1, 1]]
# typeof(output_gpu) = MtlArray{Float32, 4, Metal.PrivateStorage}
# "GPU computation of Ajiννᶜ: done" = "GPU computation of Ajiννᶜ: done"
# nodeValue = eachα.node = κ
# (vars, iVars) = (f(x), 1)
# (vars, iVars) = (f(x), 1)
# pointsIndices = availablePointsConfigurations[iConfigGeometry] = SVector{1, Int64}[[1], [2], [3]]
# middleLinearν = centrePointConfigurations[iConfigGeometry] = 2
# μPoints = availableμPoints[iConfigGeometry] = SVector{1, Float64}[[2.0]]
# μᶜPoints = availableμᶜPoints[iConfigGeometry] = SVector{1, Float64}[[2.0]]
# μaxes = availableμaxes[iConfigGeometry] = ([2.0],)
# μᶜaxes = availableμᶜaxes[iConfigGeometry] = ([2.0],)
# size(μPoints) = (1,)
# pointν = pointsIndices[middleLinearν] = [2]
# (typeof(μPoints), μPoints[1], typeof(pointsIndices)) = (Vector{SVector{1, Float64}}, [2.0], Vector{SVector{1, Int64}})
# nTotalSmallα = sum((length(bigα[iExpr, iField]) for iField = 1:NtypeofFields, iExpr = 1:NtypeofExpr)) = 1
# all_sizes = collect.(size.(coefWYYKK)) = [[4, 4, 1, 1, 1]]
# typeof(output_gpu) = MtlArray{Float32, 4, Metal.PrivateStorage}
# "GPU computation of Ajiννᶜ: done" = "GPU computation of Ajiννᶜ: done"
# nodeValue = eachα.node = 1
# 3×1×1×1 Array{Symbolics.Num, 4}:
# [:, :, 1, 1] =
#            κ₁
#  -1.9999999κ₁
#            κ₁

# %%
orderBspace=2
orderBtime=1


pointsInSpace=3
pointsInTime=1

# the order of errors to be controlled
supplementaryOrder=1

# new parameters for interpolated Taylor expansion μ for field

fieldItpl = (ptsSpace = 1,ptsTime = 1,offsetSpace=1,offsetTime=1,YorderBspace=-1,YorderBtime=1) #offsetSpace and offsetTime ∈ z 
# μ points should be distributed from y_min+offset*Δy to y_max-offset*Δy offset can be negative too


# new parameters for interpolated Taylor expansion μᶜ for material
materItpl = (ptsSpace = 1,ptsTime = 1,offsetSpace=1,offsetTime=1,YorderBspace=-1,YorderBtime=1)

concreteParametersForOPTConstruction = @strdict famousEquationType Δ orderBtime orderBspace pointsInSpace pointsInTime supplementaryOrder fieldItpl materItpl
optRec = makeOPTsemiSymbolic(concreteParametersForOPTConstruction)
recette = optRec["recette"]
Ajiννᶜ = optRec["recette"].lhs.Ajiννᶜ
# Out:
# (vars, iVars) = (κ, 1)
# (vars, iVars) = (κ, 1)
# pointsIndices = availablePointsConfigurations[iConfigGeometry] = SVector{1, Int64}[[1], [2], [3]]
# middleLinearν = centrePointConfigurations[iConfigGeometry] = 2
# μPoints = availableμPoints[iConfigGeometry] = SVector{1, Float64}[[2.0]]
# μᶜPoints = availableμᶜPoints[iConfigGeometry] = SVector{1, Float64}[[2.0]]
# μaxes = availableμaxes[iConfigGeometry] = ([2.0],)
# μᶜaxes = availableμᶜaxes[iConfigGeometry] = ([2.0],)
# size(μPoints) = (1,)
# pointν = pointsIndices[middleLinearν] = [2]
# (typeof(μPoints), μPoints[1], typeof(pointsIndices)) = (Vector{SVector{1, Float64}}, [2.0], Vector{SVector{1, Int64}})
# nTotalSmallα = sum((length(bigα[iExpr, iField]) for iField = 1:NtypeofFields, iExpr = 1:NtypeofExpr)) = 1
# all_sizes = collect.(size.(coefWYYKK)) = [[4, 4, 1, 1, 1]]
# typeof(output_gpu) = MtlArray{Float32, 4, Metal.PrivateStorage}
# "GPU computation of Ajiννᶜ: done" = "GPU computation of Ajiννᶜ: done"
# nodeValue = eachα.node = κ
# (vars, iVars) = (f(x), 1)
# (vars, iVars) = (f(x), 1)
# pointsIndices = availablePointsConfigurations[iConfigGeometry] = SVector{1, Int64}[[1], [2], [3]]
# middleLinearν = centrePointConfigurations[iConfigGeometry] = 2
# μPoints = availableμPoints[iConfigGeometry] = SVector{1, Float64}[[2.0]]
# μᶜPoints = availableμᶜPoints[iConfigGeometry] = SVector{1, Float64}[[2.0]]
# μaxes = availableμaxes[iConfigGeometry] = ([2.0],)
# μᶜaxes = availableμᶜaxes[iConfigGeometry] = ([2.0],)
# size(μPoints) = (1,)
# pointν = pointsIndices[middleLinearν] = [2]
# (typeof(μPoints), μPoints[1], typeof(pointsIndices)) = (Vector{SVector{1, Float64}}, [2.0], Vector{SVector{1, Int64}})
# nTotalSmallα = sum((length(bigα[iExpr, iField]) for iField = 1:NtypeofFields, iExpr = 1:NtypeofExpr)) = 1
# all_sizes = collect.(size.(coefWYYKK)) = [[4, 4, 1, 1, 1]]
# typeof(output_gpu) = MtlArray{Float32, 4, Metal.PrivateStorage}
# "GPU computation of Ajiννᶜ: done" = "GPU computation of Ajiννᶜ: done"
# nodeValue = eachα.node = 1
# 3×1×1×1 Array{Symbolics.Num, 4}:
# [:, :, 1, 1] =
#   0.8096847κ₁
#  -1.6666666κ₁
#  0.85698193κ₁

# %%
orderBspace=-1
orderBtime=1


pointsInSpace=5
pointsInTime=1

# the order of errors to be controlled
supplementaryOrder=2

# new parameters for interpolated Taylor expansion μ for field

fieldItpl = (ptsSpace = 1,ptsTime = 1,offsetSpace=2,offsetTime=1,YorderBspace=-1,YorderBtime=1) #offsetSpace and offsetTime ∈ z 
# μ points should be distributed from y_min+offset*Δy to y_max-offset*Δy offset can be negative too


# new parameters for interpolated Taylor expansion μᶜ for material
materItpl = (ptsSpace = 1,ptsTime = 1,offsetSpace=2,offsetTime=1,YorderBspace=-1,YorderBtime=1)

concreteParametersForOPTConstruction = @strdict famousEquationType Δ orderBtime orderBspace pointsInSpace pointsInTime supplementaryOrder fieldItpl materItpl
optRec = makeOPTsemiSymbolic(concreteParametersForOPTConstruction)
recette = optRec["recette"]
Ajiννᶜ = optRec["recette"].lhs.Ajiννᶜ
# Out:
# (vars, iVars) = (κ, 1)
# (vars, iVars) = (κ, 1)
# pointsIndices = availablePointsConfigurations[iConfigGeometry] = SVector{1, Int64}[[1], [2], [3], [4], [5]]
# middleLinearν = centrePointConfigurations[iConfigGeometry] = 3
# μPoints = availableμPoints[iConfigGeometry] = SVector{1, Float64}[[3.0]]
# μᶜPoints = availableμᶜPoints[iConfigGeometry] = SVector{1, Float64}[[3.0]]
# μaxes = availableμaxes[iConfigGeometry] = ([3.0],)
# μᶜaxes = availableμᶜaxes[iConfigGeometry] = ([3.0],)
# size(μPoints) = (1,)
# pointν = pointsIndices[middleLinearν] = [3]
# (typeof(μPoints), μPoints[1], typeof(pointsIndices)) = (Vector{SVector{1, Float64}}, [3.0], Vector{SVector{1, Int64}})
# nTotalSmallα = sum((length(bigα[iExpr, iField]) for iField = 1:NtypeofFields, iExpr = 1:NtypeofExpr)) = 1
# all_sizes = collect.(size.(coefWYYKK)) = [[7, 7, 1, 1, 1]]
# typeof(output_gpu) = MtlArray{Float32, 4, Metal.PrivateStorage}
# "GPU computation of Ajiννᶜ: done" = "GPU computation of Ajiννᶜ: done"
# nodeValue = eachα.node = κ
# (vars, iVars) = (f(x), 1)
# (vars, iVars) = (f(x), 1)
# pointsIndices = availablePointsConfigurations[iConfigGeometry] = SVector{1, Int64}[[1], [2], [3], [4], [5]]
# middleLinearν = centrePointConfigurations[iConfigGeometry] = 3
# μPoints = availableμPoints[iConfigGeometry] = SVector{1, Float64}[[3.0]]
# μᶜPoints = availableμᶜPoints[iConfigGeometry] = SVector{1, Float64}[[3.0]]
# μaxes = availableμaxes[iConfigGeometry] = ([3.0],)
# μᶜaxes = availableμᶜaxes[iConfigGeometry] = ([3.0],)
# size(μPoints) = (1,)
# pointν = pointsIndices[middleLinearν] = [3]
# (typeof(μPoints), μPoints[1], typeof(pointsIndices)) = (Vector{SVector{1, Float64}}, [3.0], Vector{SVector{1, Int64}})
# nTotalSmallα = sum((length(bigα[iExpr, iField]) for iField = 1:NtypeofFields, iExpr = 1:NtypeofExpr)) = 1
# all_sizes = collect.(size.(coefWYYKK)) = [[7, 7, 1, 1, 1]]
# typeof(output_gpu) = MtlArray{Float32, 4, Metal.PrivateStorage}
# "GPU computation of Ajiννᶜ: done" = "GPU computation of Ajiννᶜ: done"
# nodeValue = eachα.node = 1
# 5×1×1×1 Array{Symbolics.Num, 4}:
# [:, :, 1, 1] =
#    2.355073κ₁
#  -5.4217334κ₁
#    6.133316κ₁
#   -5.421734κ₁
#    2.355073κ₁
